# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yining
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 1 | honiara
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 1 | tillabery
# City not found. Skipping...
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | alice springs
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | wajir
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | beringovskiy
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | angoche
# Processing Record 24 of Set 1 | trinidad
# Processing Record 25 of Set 1 | kurchum
# Processing Record 26 of Set 1 | port-gentil
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | batagay-alyta
# Processing Record 31 of Set 1 | kautokeino
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | ramotswa
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | west bay
# Processing Record 37 of Set 1 | labuan
# Processing Record 38 of Set 1 | pacific grove
# Processing Record 39 of Set 1 | chara
# Processing Record 40 of Set 1 | ambulu
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | komsomolskiy
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | lahij
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | mackay
# Processing Record 49 of Set 1 | zyryanka
# Processing Record 50 of Set 1 | thunder bay
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | hamilton
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | kawalu
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | maarianhamina
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | sitka
# Processing Record 18 of Set 2 | nova vcelnice
# Processing Record 19 of Set 2 | guasdualito
# Processing Record 20 of Set 2 | lakes entrance
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | guantanamo
# Processing Record 24 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | sinnamary
# Processing Record 27 of Set 2 | urengoy
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | oktyabrskaya
# City not found. Skipping...
# Processing Record 32 of Set 2 | san ramon de la nueva oran
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | tamandare
# Processing Record 36 of Set 2 | clyde river
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | vestmannaeyjar
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | asau
# Processing Record 41 of Set 2 | san marcos
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | itarema
# Processing Record 44 of Set 2 | sukumo
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | esperance
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | sola
# Processing Record 50 of Set 2 | pangnirtung
# Processing Record 1 of Set 3 | mulatupo
# Processing Record 2 of Set 3 | chenghai
# Processing Record 3 of Set 3 | san joaquin
# Processing Record 4 of Set 3 | seminole
# Processing Record 5 of Set 3 | rutul
# Processing Record 6 of Set 3 | la ronge
# Processing Record 7 of Set 3 | kapit
# Processing Record 8 of Set 3 | kapaa
# Processing Record 9 of Set 3 | port lincoln
# Processing Record 10 of Set 3 | aksarka
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | havelock
# Processing Record 13 of Set 3 | robat karim
# Processing Record 14 of Set 3 | correntina
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | jumla
# Processing Record 17 of Set 3 | stromness
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | prachuap khiri khan
# Processing Record 20 of Set 3 | matagami
# Processing Record 21 of Set 3 | salalah
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | kruisfontein
# Processing Record 24 of Set 3 | hirara
# Processing Record 25 of Set 3 | faya
# Processing Record 26 of Set 3 | hovd
# Processing Record 27 of Set 3 | qaqortoq
# Processing Record 28 of Set 3 | bud
# Processing Record 29 of Set 3 | broome
# Processing Record 30 of Set 3 | nioro
# Processing Record 31 of Set 3 | tutoia
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | luderitz
# Processing Record 35 of Set 3 | te anau
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | storforshei
# Processing Record 40 of Set 3 | sechura
# Processing Record 41 of Set 3 | pendleton
# Processing Record 42 of Set 3 | tambovka
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | gumushane
# City not found. Skipping...
# Processing Record 46 of Set 3 | birobidzhan
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | sorland
# Processing Record 49 of Set 3 | innisfail
# Processing Record 50 of Set 3 | batticaloa
# Processing Record 1 of Set 4 | pareora
# Processing Record 2 of Set 4 | buraydah
# Processing Record 3 of Set 4 | gizo
# Processing Record 4 of Set 4 | yuncheng
# Processing Record 5 of Set 4 | nemuro
# Processing Record 6 of Set 4 | falun
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | rawson
# Processing Record 9 of Set 4 | rio gallegos
# Processing Record 10 of Set 4 | college
# Processing Record 11 of Set 4 | meulaboh
# Processing Record 12 of Set 4 | akyab
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | betioky
# Processing Record 15 of Set 4 | zhanaozen
# Processing Record 16 of Set 4 | rocha
# Processing Record 17 of Set 4 | chicama
# Processing Record 18 of Set 4 | puerto ayora
# Processing Record 19 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | leningradskiy
# Processing Record 22 of Set 4 | dingle
# Processing Record 23 of Set 4 | kitgum
# Processing Record 24 of Set 4 | reconquista
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | hualmay
# Processing Record 28 of Set 4 | ye
# City not found. Skipping...
# Processing Record 29 of Set 4 | carutapera
# Processing Record 30 of Set 4 | pontianak
# Processing Record 31 of Set 4 | sao jose da coroa grande
# Processing Record 32 of Set 4 | berea
# Processing Record 33 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 4 | vardo
# Processing Record 35 of Set 4 | vodnyy
# Processing Record 36 of Set 4 | bulgan
# Processing Record 37 of Set 4 | kashi
# Processing Record 38 of Set 4 | sioux lookout
# Processing Record 39 of Set 4 | ponta delgada
# Processing Record 40 of Set 4 | shingu
# Processing Record 41 of Set 4 | panama city
# Processing Record 42 of Set 4 | iwanai
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | morgantown
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | marawi
# Processing Record 47 of Set 4 | winnemucca
# Processing Record 48 of Set 4 | chardara
# Processing Record 49 of Set 4 | quelimane
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | port moresby
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | solnechnyy
# Processing Record 5 of Set 5 | buzmeyin
# Processing Record 6 of Set 5 | popondetta
# Processing Record 7 of Set 5 | raudeberg
# Processing Record 8 of Set 5 | sandnessjoen
# Processing Record 9 of Set 5 | san roque
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | fountain hills
# Processing Record 12 of Set 5 | konosha
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | araouane
# Processing Record 15 of Set 5 | nishihara
# Processing Record 16 of Set 5 | pagudpud
# Processing Record 17 of Set 5 | guangyuan
# Processing Record 18 of Set 5 | mormugao
# Processing Record 19 of Set 5 | ngunguru
# Processing Record 20 of Set 5 | zeya
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | talnakh
# Processing Record 23 of Set 5 | pointe michel
# Processing Record 24 of Set 5 | bambanglipuro
# Processing Record 25 of Set 5 | adrar
# Processing Record 26 of Set 5 | samarai
# Processing Record 27 of Set 5 | katherine
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | chuy
# Processing Record 30 of Set 5 | arlit
# Processing Record 31 of Set 5 | camana
# Processing Record 32 of Set 5 | emerald
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | georgetown
# Processing Record 35 of Set 5 | proletariy
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | sume
# Processing Record 38 of Set 5 | skibbereen
# Processing Record 39 of Set 5 | zhezkazgan
# Processing Record 40 of Set 5 | mount gambier
# Processing Record 41 of Set 5 | cukai
# Processing Record 42 of Set 5 | mahebourg
# Processing Record 43 of Set 5 | ukiah
# Processing Record 44 of Set 5 | sao felix do xingu
# Processing Record 45 of Set 5 | caucaia
# Processing Record 46 of Set 5 | tiblawan
# Processing Record 47 of Set 5 | inhambane
# Processing Record 48 of Set 5 | okhotsk
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | toropets
# Processing Record 1 of Set 6 | medina
# Processing Record 2 of Set 6 | boyle
# Processing Record 3 of Set 6 | laela
# Processing Record 4 of Set 6 | mehamn
# Processing Record 5 of Set 6 | andenes
# Processing Record 6 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 6 | mount isa
# Processing Record 8 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 6 | northam
# Processing Record 10 of Set 6 | golyshmanovo
# Processing Record 11 of Set 6 | atar
# Processing Record 12 of Set 6 | ostrovnoy
# Processing Record 13 of Set 6 | borama
# City not found. Skipping...
# Processing Record 14 of Set 6 | seydi
# Processing Record 15 of Set 6 | surgut
# Processing Record 16 of Set 6 | treinta y tres
# Processing Record 17 of Set 6 | cabedelo
# Processing Record 18 of Set 6 | burdur
# Processing Record 19 of Set 6 | urucui
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | saint-augustin
# Processing Record 22 of Set 6 | uvat
# Processing Record 23 of Set 6 | nagato
# Processing Record 24 of Set 6 | buin
# Processing Record 25 of Set 6 | nuuk
# Processing Record 26 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 6 | moa
# Processing Record 28 of Set 6 | sambava
# Processing Record 29 of Set 6 | martapura
# Processing Record 30 of Set 6 | morinville
# Processing Record 31 of Set 6 | maningrida
# Processing Record 32 of Set 6 | los llanos de aridane
# Processing Record 33 of Set 6 | alta floresta
# Processing Record 34 of Set 6 | vyartsilya
# Processing Record 35 of Set 6 | karabuk
# Processing Record 36 of Set 6 | nizwa
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | dunmore east
# Processing Record 39 of Set 6 | burica
# City not found. Skipping...
# Processing Record 40 of Set 6 | adamantina
# Processing Record 41 of Set 6 | kendal
# Processing Record 42 of Set 6 | perepravnaya
# Processing Record 43 of Set 6 | avera
# Processing Record 44 of Set 6 | baykit
# Processing Record 45 of Set 6 | kamyshevatskaya
# Processing Record 46 of Set 6 | mogadishu
# Processing Record 47 of Set 6 | hambantota
# Processing Record 48 of Set 6 | magdalena
# Processing Record 49 of Set 6 | farafangana
# Processing Record 50 of Set 6 | flinders
# Processing Record 1 of Set 7 | srednekolymsk
# Processing Record 2 of Set 7 | yerbogachen
# Processing Record 3 of Set 7 | bonavista
# Processing Record 4 of Set 7 | sagae
# Processing Record 5 of Set 7 | sapa
# Processing Record 6 of Set 7 | bardiyah
# Processing Record 7 of Set 7 | suez
# Processing Record 8 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 9 of Set 7 | poiana blenchii
# Processing Record 10 of Set 7 | cap-haitien
# Processing Record 11 of Set 7 | antofagasta
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | emporia
# Processing Record 14 of Set 7 | outram
# Processing Record 15 of Set 7 | guarapari
# Processing Record 16 of Set 7 | bathsheba
# Processing Record 17 of Set 7 | pucallpa
# Processing Record 18 of Set 7 | black forest
# Processing Record 19 of Set 7 | ternate
# Processing Record 20 of Set 7 | comodoro rivadavia
# Processing Record 21 of Set 7 | kenai
# Processing Record 22 of Set 7 | alpena
# Processing Record 23 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 7 | faanui
# Processing Record 25 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 7 | nouadhibou
# Processing Record 27 of Set 7 | capao da canoa
# Processing Record 28 of Set 7 | ladushkin
# Processing Record 29 of Set 7 | noumea
# Processing Record 30 of Set 7 | boma
# Processing Record 31 of Set 7 | lubaczow
# Processing Record 32 of Set 7 | taua
# Processing Record 33 of Set 7 | sao joao del rei
# Processing Record 34 of Set 7 | eureka
# Processing Record 35 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 7 | esmeraldas
# Processing Record 37 of Set 7 | santa maria
# Processing Record 38 of Set 7 | olenino
# Processing Record 39 of Set 7 | narsaq
# Processing Record 40 of Set 7 | mineros
# Processing Record 41 of Set 7 | airai
# Processing Record 42 of Set 7 | darnah
# Processing Record 43 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 7 | pevek
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | ilhabela
# Processing Record 48 of Set 7 | igrim
# Processing Record 49 of Set 7 | hamirpur
# Processing Record 50 of Set 7 | port-cartier
# Processing Record 1 of Set 8 | blagoyevo
# Processing Record 2 of Set 8 | san patricio
# Processing Record 3 of Set 8 | flin flon
# Processing Record 4 of Set 8 | hazleton
# Processing Record 5 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 8 | general roca
# Processing Record 8 of Set 8 | santiago de cuba
# Processing Record 9 of Set 8 | gao
# Processing Record 10 of Set 8 | pervomayskoye
# Processing Record 11 of Set 8 | zhigansk
# Processing Record 12 of Set 8 | fukue
# Processing Record 13 of Set 8 | bagacay
# Processing Record 14 of Set 8 | yertsevo
# Processing Record 15 of Set 8 | tuatapere
# Processing Record 16 of Set 8 | srebrenica
# Processing Record 17 of Set 8 | voi
# Processing Record 18 of Set 8 | kattivakkam
# Processing Record 19 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 8 | acajutla
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | cherskiy
# Processing Record 23 of Set 8 | bayonet point
# Processing Record 24 of Set 8 | kieta
# Processing Record 25 of Set 8 | kendari
# Processing Record 26 of Set 8 | stantsionno-oyashinskiy
# Processing Record 27 of Set 8 | fortuna
# Processing Record 28 of Set 8 | niquero
# Processing Record 29 of Set 8 | houston
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | norman wells
# Processing Record 32 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 33 of Set 8 | tatarsk
# Processing Record 34 of Set 8 | alekseyevsk
# Processing Record 35 of Set 8 | henties bay
# Processing Record 36 of Set 8 | lokomotivnyy
# Processing Record 37 of Set 8 | paranagua
# Processing Record 38 of Set 8 | portland
# Processing Record 39 of Set 8 | mayo
# Processing Record 40 of Set 8 | kirishi
# Processing Record 41 of Set 8 | palmas
# Processing Record 42 of Set 8 | ancud
# Processing Record 43 of Set 8 | gold coast
# Processing Record 44 of Set 8 | rafai
# Processing Record 45 of Set 8 | hlukhiv
# Processing Record 46 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 8 | evensk
# Processing Record 48 of Set 8 | calbuco
# Processing Record 49 of Set 8 | thaton
# Processing Record 50 of Set 8 | baft
# Processing Record 1 of Set 9 | aberdeen
# Processing Record 2 of Set 9 | buritizeiro
# Processing Record 3 of Set 9 | siclong
# Processing Record 4 of Set 9 | rensvik
# Processing Record 5 of Set 9 | san cristobal
# Processing Record 6 of Set 9 | montijo
# Processing Record 7 of Set 9 | tommot
# Processing Record 8 of Set 9 | kudahuvadhoo
# Processing Record 9 of Set 9 | falaleu
# City not found. Skipping...
# Processing Record 10 of Set 9 | roald
# Processing Record 11 of Set 9 | najran
# Processing Record 12 of Set 9 | uarini
# Processing Record 13 of Set 9 | godfrey
# Processing Record 14 of Set 9 | verin
# Processing Record 15 of Set 9 | anadyr
# Processing Record 16 of Set 9 | coihaique
# Processing Record 17 of Set 9 | sharjah
# Processing Record 18 of Set 9 | chusovoy
# Processing Record 19 of Set 9 | kemise
# Processing Record 20 of Set 9 | tateyama
# Processing Record 21 of Set 9 | maniitsoq
# Processing Record 22 of Set 9 | shakiso
# Processing Record 23 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 9 | shimoda
# Processing Record 25 of Set 9 | dalvik
# Processing Record 26 of Set 9 | dunedin
# Processing Record 27 of Set 9 | kargat
# Processing Record 28 of Set 9 | birao
# Processing Record 29 of Set 9 | shediac
# Processing Record 30 of Set 9 | imeni babushkina
# Processing Record 31 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 9 | iskateley
# Processing Record 33 of Set 9 | bacalar
# Processing Record 34 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 9 | humberto de campos
# Processing Record 36 of Set 9 | tonekabon
# Processing Record 37 of Set 9 | haines junction
# Processing Record 38 of Set 9 | methven
# Processing Record 39 of Set 9 | beidao
# Processing Record 40 of Set 9 | kachiry
# Processing Record 41 of Set 9 | coquimbo
# Processing Record 42 of Set 9 | kaseda
# Processing Record 43 of Set 9 | caico
# Processing Record 44 of Set 9 | torbay
# Processing Record 45 of Set 9 | nicoya
# Processing Record 46 of Set 9 | paignton
# Processing Record 47 of Set 9 | port hawkesbury
# Processing Record 48 of Set 9 | candolim
# Processing Record 49 of Set 9 | lithgow
# Processing Record 50 of Set 9 | ape
# Processing Record 1 of Set 10 | galveston
# Processing Record 2 of Set 10 | bandarbeyla
# Processing Record 3 of Set 10 | windhoek
# Processing Record 4 of Set 10 | high level
# Processing Record 5 of Set 10 | banda aceh
# Processing Record 6 of Set 10 | filadelfia
# Processing Record 7 of Set 10 | puerto escondido
# Processing Record 8 of Set 10 | puerto palomas
# Processing Record 9 of Set 10 | codrington
# Processing Record 10 of Set 10 | cuamba
# Processing Record 11 of Set 10 | santiago del estero
# Processing Record 12 of Set 10 | mikhaylovka
# Processing Record 13 of Set 10 | hunterville
# Processing Record 14 of Set 10 | lavrentiya
# Processing Record 15 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 10 | karratha
# Processing Record 17 of Set 10 | grand-santi
# Processing Record 18 of Set 10 | alamogordo
# Processing Record 19 of Set 10 | umm lajj
# Processing Record 20 of Set 10 | north platte
# Processing Record 21 of Set 10 | santa isabel do rio negro
# Processing Record 22 of Set 10 | west plains
# Processing Record 23 of Set 10 | doha
# Processing Record 24 of Set 10 | ugoofaaru
# Processing Record 25 of Set 10 | umarkot
# Processing Record 26 of Set 10 | novyy urengoy
# Processing Record 27 of Set 10 | alyangula
# Processing Record 28 of Set 10 | kikwit
# Processing Record 29 of Set 10 | praia
# Processing Record 30 of Set 10 | amursk
# Processing Record 31 of Set 10 | nichinan
# Processing Record 32 of Set 10 | aripuana
# Processing Record 33 of Set 10 | cerritos
# Processing Record 34 of Set 10 | gamba
# Processing Record 35 of Set 10 | panaba
# Processing Record 36 of Set 10 | padang
# Processing Record 37 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 10 | luanda
# Processing Record 39 of Set 10 | mayumba
# Processing Record 40 of Set 10 | yanam
# Processing Record 41 of Set 10 | bousso
# Processing Record 42 of Set 10 | penzance
# Processing Record 43 of Set 10 | hobyo
# Processing Record 44 of Set 10 | san vicente
# Processing Record 45 of Set 10 | rocky mount
# Processing Record 46 of Set 10 | lazaro cardenas
# Processing Record 47 of Set 10 | porto novo
# Processing Record 48 of Set 10 | hofn
# Processing Record 49 of Set 10 | kashary
# Processing Record 50 of Set 10 | kisangani
# Processing Record 1 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 11 | aksha
# Processing Record 3 of Set 11 | salina
# Processing Record 4 of Set 11 | fairbanks
# Processing Record 5 of Set 11 | saint-pierre
# Processing Record 6 of Set 11 | chapais
# Processing Record 7 of Set 11 | ossora
# Processing Record 8 of Set 11 | dongsheng
# Processing Record 9 of Set 11 | richards bay
# Processing Record 10 of Set 11 | vanavara
# Processing Record 11 of Set 11 | makakilo city
# Processing Record 12 of Set 11 | khandagayty
# Processing Record 13 of Set 11 | nilopolis
# Processing Record 14 of Set 11 | luis correia
# Processing Record 15 of Set 11 | murbad
# Processing Record 16 of Set 11 | berlevag
# Processing Record 17 of Set 11 | tawang
# Processing Record 18 of Set 11 | hachinohe
# Processing Record 19 of Set 11 | nukus
# Processing Record 20 of Set 11 | elblag
# Processing Record 21 of Set 11 | kvitok
# Processing Record 22 of Set 11 | botwood
# Processing Record 23 of Set 11 | chimbote
# Processing Record 24 of Set 11 | antalaha
# Processing Record 25 of Set 11 | nouakchott
# Processing Record 26 of Set 11 | puerto madryn
# Processing Record 27 of Set 11 | harper
# Processing Record 28 of Set 11 | mazatlan
# Processing Record 29 of Set 11 | chirongui
# Processing Record 30 of Set 11 | madison
# Processing Record 31 of Set 11 | eirunepe
# Processing Record 32 of Set 11 | wasilla
# Processing Record 33 of Set 11 | sakakah
# Processing Record 34 of Set 11 | tiksi
# Processing Record 35 of Set 11 | tilaran
# Processing Record 36 of Set 11 | manuk mangkaw
# Processing Record 37 of Set 11 | labuhan
# Processing Record 38 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 11 | duluth
# Processing Record 40 of Set 11 | terrace bay
# Processing Record 41 of Set 11 | qiongshan
# Processing Record 42 of Set 11 | kahului
# Processing Record 43 of Set 11 | la paz
# Processing Record 44 of Set 11 | kaeo
# Processing Record 45 of Set 11 | khajuraho
# Processing Record 46 of Set 11 | poum
# Processing Record 47 of Set 11 | champasak
# Processing Record 48 of Set 11 | yumen
# Processing Record 49 of Set 11 | biak
# Processing Record 50 of Set 11 | vuktyl
# Processing Record 1 of Set 12 | yar-sale
# Processing Record 2 of Set 12 | opuwo
# Processing Record 3 of Set 12 | luena
# Processing Record 4 of Set 12 | qasigiannguit
# Processing Record 5 of Set 12 | iwo
# Processing Record 6 of Set 12 | kasongo
# Processing Record 7 of Set 12 | puerto carreno
# Processing Record 8 of Set 12 | sungai siput utara
# City not found. Skipping...
# Processing Record 9 of Set 12 | beipiao
# Processing Record 10 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 12 | erenhot
# Processing Record 12 of Set 12 | konstantinovka
# Processing Record 13 of Set 12 | dolores
# Processing Record 14 of Set 12 | sheridan
# Processing Record 15 of Set 12 | muhos
# Processing Record 16 of Set 12 | phan thiet
# Processing Record 17 of Set 12 | kavieng
# Processing Record 18 of Set 12 | finote selam
# Processing Record 19 of Set 12 | moose factory
# Processing Record 20 of Set 12 | buala
# Processing Record 21 of Set 12 | nome
# Processing Record 22 of Set 12 | barra do bugres
# Processing Record 23 of Set 12 | inverell
# Processing Record 24 of Set 12 | pitimbu
# Processing Record 25 of Set 12 | madang
# Processing Record 26 of Set 12 | manado
# Processing Record 27 of Set 12 | tazovskiy
# Processing Record 28 of Set 12 | swellendam
# Processing Record 29 of Set 12 | vao
# Processing Record 30 of Set 12 | bourail
# Processing Record 31 of Set 12 | marrakesh
# Processing Record 32 of Set 12 | jaunjelgava
# Processing Record 33 of Set 12 | camopi
# Processing Record 34 of Set 12 | goure
# Processing Record 35 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 12 | leh
# Processing Record 37 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 12 | wanning
# Processing Record 39 of Set 12 | kovur
# Processing Record 40 of Set 12 | ulaanbaatar
# Processing Record 41 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 12 | nurota
# Processing Record 43 of Set 12 | husavik
# Processing Record 44 of Set 12 | mombetsu
# Processing Record 45 of Set 12 | alberton
# Processing Record 46 of Set 12 | belmonte
# Processing Record 47 of Set 12 | minot
# Processing Record 48 of Set 12 | baiao
# Processing Record 49 of Set 12 | umm kaddadah
# Processing Record 50 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 1 of Set 13 | pokhara
# Processing Record 2 of Set 13 | carnot
# Processing Record 3 of Set 13 | juneau
# Processing Record 4 of Set 13 | kropotkin
# Processing Record 5 of Set 13 | havre-saint-pierre
# Processing Record 6 of Set 13 | kamenka
# Processing Record 7 of Set 13 | langsa
# Processing Record 8 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 13 | fengrun
# Processing Record 11 of Set 13 | vire
# Processing Record 12 of Set 13 | oktyabrskiy
# Processing Record 13 of Set 13 | rolla
# Processing Record 14 of Set 13 | san jose
# Processing Record 15 of Set 13 | anchorage
# Processing Record 16 of Set 13 | kavaratti
# Processing Record 17 of Set 13 | sidney
# Processing Record 18 of Set 13 | turukhansk
# Processing Record 19 of Set 13 | fez
# Processing Record 20 of Set 13 | deputatskiy
# Processing Record 21 of Set 13 | dawei
# Processing Record 22 of Set 13 | alakurtti
# Processing Record 23 of Set 13 | moiyabana
# City not found. Skipping...
# Processing Record 24 of Set 13 | caravelas
# Processing Record 25 of Set 13 | novikovo
# Processing Record 26 of Set 13 | porbandar
# Processing Record 27 of Set 13 | foam lake
# Processing Record 28 of Set 13 | bonfim
# Processing Record 29 of Set 13 | korla
# Processing Record 30 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 13 | saint-georges
# Processing Record 32 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 33 of Set 13 | sabha
# Processing Record 34 of Set 13 | coahuayana
# Processing Record 35 of Set 13 | nalut
# Processing Record 36 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 37 of Set 13 | cumana
# Processing Record 38 of Set 13 | maldonado
# Processing Record 39 of Set 13 | guadalupe y calvo
# Processing Record 40 of Set 13 | tautira
# Processing Record 41 of Set 13 | santa rosa
# Processing Record 42 of Set 13 | chemal
# Processing Record 43 of Set 13 | tubmanburg
# Processing Record 44 of Set 13 | eyemouth
# Processing Record 45 of Set 13 | micheweni
# Processing Record 46 of Set 13 | anjozorobe
# Processing Record 47 of Set 13 | havoysund
# Processing Record 48 of Set 13 | vila velha
# Processing Record 49 of Set 13 | bemidji
# Processing Record 50 of Set 13 | namibe
# Processing Record 1 of Set 14 | sindor
# Processing Record 2 of Set 14 | belaya gora
# Processing Record 3 of Set 14 | gogrial
# Processing Record 4 of Set 14 | durban
# Processing Record 5 of Set 14 | chiredzi
# Processing Record 6 of Set 14 | areni
# Processing Record 7 of Set 14 | yarmouth
# Processing Record 8 of Set 14 | matay
# Processing Record 9 of Set 14 | port augusta
# Processing Record 10 of Set 14 | presidente olegario
# Processing Record 11 of Set 14 | katsuura
# Processing Record 12 of Set 14 | rundu
# Processing Record 13 of Set 14 | along
# Processing Record 14 of Set 14 | grindavik
# Processing Record 15 of Set 14 | tuy hoa
# Processing Record 16 of Set 14 | sinnai
# Processing Record 17 of Set 14 | campbell river
# Processing Record 18 of Set 14 | redlands
# Processing Record 19 of Set 14 | cacador
# Processing Record 20 of Set 14 | roma
# Processing Record 21 of Set 14 | socorro
# Processing Record 22 of Set 14 | san carlos de bariloche
# Processing Record 23 of Set 14 | itoman
# Processing Record 24 of Set 14 | norrtalje
# Processing Record 25 of Set 14 | pangody
# Processing Record 26 of Set 14 | vila
# Processing Record 27 of Set 14 | kabinda
# Processing Record 28 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 14 | boa vista
# Processing Record 30 of Set 14 | hay river
# Processing Record 31 of Set 14 | yilan
# Processing Record 32 of Set 14 | ozuluama
# Processing Record 33 of Set 14 | imbituba
# Processing Record 34 of Set 14 | narkevychi
# Processing Record 35 of Set 14 | kambove
# Processing Record 36 of Set 14 | sungaipenuh
# Processing Record 37 of Set 14 | kollam
# Processing Record 38 of Set 14 | saint-francois
# Processing Record 39 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 14 | toktogul
# Processing Record 41 of Set 14 | mangrol
# Processing Record 42 of Set 14 | san quintin
# Processing Record 43 of Set 14 | emba
# Processing Record 44 of Set 14 | hoquiam
# Processing Record 45 of Set 14 | coelho neto
# Processing Record 46 of Set 14 | andra
# Processing Record 47 of Set 14 | soller
# Processing Record 48 of Set 14 | seybaplaya
# Processing Record 49 of Set 14 | tra vinh
# Processing Record 50 of Set 14 | fort nelson
# Processing Record 1 of Set 15 | gazanjyk
# Processing Record 2 of Set 15 | ambon
# Processing Record 3 of Set 15 | balakhta
# Processing Record 4 of Set 15 | cayenne
# Processing Record 5 of Set 15 | shahr-e babak
# Processing Record 6 of Set 15 | moba
# Processing Record 7 of Set 15 | paamiut
# Processing Record 8 of Set 15 | bubaque
# Processing Record 9 of Set 15 | alofi
# Processing Record 10 of Set 15 | palmares do sul
# Processing Record 11 of Set 15 | dinghai
# Processing Record 12 of Set 15 | teguldet
# Processing Record 13 of Set 15 | inirida
# Processing Record 14 of Set 15 | ciudad bolivar
# Processing Record 15 of Set 15 | chimore
# Processing Record 16 of Set 15 | yokadouma
# Processing Record 17 of Set 15 | sakaiminato
# Processing Record 18 of Set 15 | carauari
# Processing Record 19 of Set 15 | tupik
# Processing Record 20 of Set 15 | ketchikan
# Processing Record 21 of Set 15 | thiruvananthapuram
# Processing Record 22 of Set 15 | tera
# Processing Record 23 of Set 15 | pundaguitan
# Processing Record 24 of Set 15 | russell
# Processing Record 25 of Set 15 | rio bonito
# Processing Record 26 of Set 15 | marzuq
# Processing Record 27 of Set 15 | yanji
# Processing Record 28 of Set 15 | bolobo
# Processing Record 29 of Set 15 | seoul
# Processing Record 30 of Set 15 | senador jose porfirio
# Processing Record 31 of Set 15 | kijang
# Processing Record 32 of Set 15 | lata
# Processing Record 33 of Set 15 | jinji
# Processing Record 34 of Set 15 | alausi
# Processing Record 35 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 36 of Set 15 | musafirkhana
# Processing Record 37 of Set 15 | muktagachha
# City not found. Skipping...
# Processing Record 38 of Set 15 | bukama
# Processing Record 39 of Set 15 | keti bandar
# Processing Record 40 of Set 15 | puro
# Processing Record 41 of Set 15 | prince rupert
# Processing Record 42 of Set 15 | bure
# Processing Record 43 of Set 15 | puerto narino
# Processing Record 44 of Set 15 | lahad datu
# Processing Record 45 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 47 of Set 15 | saint-louis
# Processing Record 48 of Set 15 | jiaocheng
# Processing Record 49 of Set 15 | bilma
# Processing Record 50 of Set 15 | kayankulam
# Processing Record 1 of Set 16 | bolshevik
# Processing Record 2 of Set 16 | sebezh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Yining      CN  29.0361  114.5636     71.80        82          24
# 1        Rikitea      PF -23.1203 -134.9692     67.03        88         100
# 2        Ushuaia      AR -54.8000  -68.3000     40.62        75          75
# 3  Mar Del Plata      AR -38.0023  -57.5575     62.01        60           0
# 4         Barrow      US  71.2906 -156.7887     35.62        87          90
# 5        Honiara      SB  -9.4333  159.9500     76.59        89          62
# 6      Cape Town      ZA -33.9258   18.4232     72.12        68           0
# 7  Alice Springs      AU -23.7000  133.8833     67.55        94          90
# 8    Yellowknife      CA  62.4560 -114.3525     39.47        73          90
# 9      Saskylakh      RU  71.9167  114.0833     30.42        91          97
#
#    Wind Speed          Current Description
# 0        2.08                   few clouds
# 1        8.99                moderate rain
# 2        2.30                broken clouds
# 3       15.50                    clear sky
# 4       13.80                      drizzle
# 5        6.29                   light rain
# 6        3.00                    clear sky
# 7       10.36  light intensity shower rain
# 8        8.16              overcast clouds
# 9       11.41              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
